# %% [markdown]
# # Atividade Prática 00
# Nome: SEU_NOME

# %% [markdown]
# # Importações

# %%
# Apenas para MacOS, para resolver o problema de certificado SSL
import os
os.environ['SSL_CERT_FILE'] = '/etc/ssl/cert.pem'
os.environ['REQUESTS_CA_BUNDLE'] = '/etc/ssl/cert.pem'

# %%
import requests
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Importação do Dataset

# %%
# df = pd.read_csv('data.csv')
URL_CSV = "https://raw.githubusercontent.com/prof-mrafaelbatista/261_UNIESP_MBA-DADOS_data_mining_inferencia_estatistica/refs/heads/main/datasets/OnlineRetail.csv"

# %%
df_csv = pd.read_csv(URL_CSV, encoding='latin1')
df_csv.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Perguntas

# %% [markdown]
# ## Quantas linhas e colunas o dataset possui?

# %%
df_csv.shape
# Out:
# (541909, 8)

# %% [markdown]
# ## Quais são os tipos de dados de cada coluna?

# %%
df_csv.dtypes
# Out:
# InvoiceNo          str
# StockCode          str
# Description        str
# Quantity         int64
# InvoiceDate        str
# UnitPrice      float64
# CustomerID     float64
# Country            str
# dtype: object

# %%
df_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %% [markdown]
# ## Alguma coluna de data está como string?

# %%
# Sim, a coluna InvoiceDate

# %% [markdown]
# ## Quantos valores ausentes existem em cada coluna?

# %%
# Description: 1454
# CustomID: 135080

# %% [markdown]
# ## Qual coluna tem mais missings?

# %%
# Custom ID

# %% [markdown]
# ## Qual é o valor médio de 'UnitPrice' e qual é o produto (Description) mais caro?

# %%
df_csv['UnitPrice'].mean()
# Out:
# np.float64(4.611113626088514)

# %%
# Manual 38.970

# %% [markdown]
# ## Filtre apenas as transações do país 'France'. Quantas linhas restam?

# %%
df_csv[df_csv['Country'] == 'France'].shape
# Out:
# (8557, 8)
