# %% [markdown]
# # Atividade Prática 00
# Nome: SEU_NOME

# %% [markdown]
# # Importações

# %%
# import pandas as pd

# %% [markdown]
# # Importação do Dataset

# %%
# df = pd.read_csv('data.csv')

# %% [markdown]
# # Perguntas

# %% [markdown]
# ## pergunta_01

# %%
# Código para responder a pergunta
