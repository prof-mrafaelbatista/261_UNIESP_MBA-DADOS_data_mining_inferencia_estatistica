# %%
# Instalações

# %%
# Importações
import pandas as pd

# %%
data = pd.Series([1, 2, 3, 4, 5])

# %%
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data[1]
# Out:
# np.int64(2)

# %%
data[1:3]
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
populacao_ne = {
    'Fortaleza': 2428678,
    'Salvador' : 2418005,
    'Recife' : 1488920,
    'São Luís' : 1037775,
    'Maceió' : 957916,
    'Teresina' : 866300,
    'João Pessoa' : 833932
}

# %%
populacao = pd.Series(populacao_ne)
populacao
# Out:
# Fortaleza      2428678
# Salvador       2418005
# Recife         1488920
# São Luís       1037775
# Maceió          957916
# Teresina        866300
# João Pessoa     833932
# dtype: int64

# %%
populacao.values
# Out:
# array([2428678, 2418005, 1488920, 1037775,  957916,  866300,  833932])

# %%
populacao[2:4]
# Out:
# Recife      1488920
# São Luís    1037775
# dtype: int64

# %%
lista_exemplo = [
    [1, 2, 3, 4, 5],
    [6, 7, 8, 9, 0]
]

# %%
pop_ne = [2418005, 1488920, 833932]
area = [692.818, 218.843, 211.745]

# %%
dict_ne = {
    "pop_ne": pop_ne,
    "area": area
}

# %%
dict_ne
# Out:
# {'pop_ne': [2418005, 1488920, 833932], 'area': [692.818, 218.843, 211.745]}

# %%
# pd.DataFrame({
#     "pop_ne": pop_ne,
#     "area": area
# })

data_ne = pd.DataFrame(dict_ne)

# %%
data_ne
# Out:
#     pop_ne     area
# 0  2418005  692.818
# 1  1488920  218.843
# 2   833932  211.745

# %%
data_ne.columns
# Out:
# Index(['pop_ne', 'area'], dtype='object')

# %%
data_ne['pop_ne']
# Out:
# 0    2418005
# 1    1488920
# 2     833932
# Name: pop_ne, dtype: int64

# %%
data_ne.head(2)
# Out:
#     pop_ne     area
# 0  2418005  692.818
# 1  1488920  218.843

# %%
data_ne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pop_ne  3 non-null      int64
#  1   area    3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 180.0 bytes

# %%
data_ne.shape
# Out:
# (3, 2)

# %%
print(data_ne.shape[0])
print(data_ne.shape[1])
# Out:
# 3
# 2

# %%
data_ne['area'].unique()
# Out:
# array([692.818, 218.843, 211.745])

# %%
data_ne['pop_ne'].nunique()
# Out:
# 3

# %%
data_ne['pop_ne'].value_counts()
# Out:
# pop_ne
# 2418005    1
# 1488920    1
# 833932     1
# Name: count, dtype: int64

# %%
data_ne.count()
# Out:
# pop_ne    3
# area      3
# dtype: int64

# %%
data_ne['area'].sum()
# Out:
# np.float64(1123.406)

# %%
data_ne['pop_ne'].max()
# Out:
# 2418005

# %%
data_ne['pop_ne'].min()
# Out:
# 833932

# %%
data_ne.describe()
# Out:
#              pop_ne        area
# count  3.000000e+00    3.000000
# mean   1.580286e+06  374.468667
# std    7.959790e+05  275.721452
# min    8.339320e+05  211.745000
# 25%    1.161426e+06  215.294000
# 50%    1.488920e+06  218.843000
# 75%    1.953462e+06  455.830500
# max    2.418005e+06  692.818000
